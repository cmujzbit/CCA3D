# %%
# TODO : From where those data are taken? 
raw_data <- read.csv("../data/raw_data/rna_total_cnt.csv", header=TRUE, row.names=1)

# %%
raw_data <- na.omit(raw_data)

# %%
# TODO : English comments could be added.
# Usuwanie mirna o niskiej sumie zliczen. dla CCA (0,0,0,1) wyglada tak samo jak (0,0,0,100000), a to pierwsze moze byc wynikiem szumu
rna_sum_threshold <- 20
rna_sum_thr_mask <- rowSums(raw_data) > rna_sum_threshold
# TODO : This mask were not applied in oryginal script? Not to big impact if comapred with 2log fold change filter.
raw_data <- raw_data[rna_sum_thr_mask,]

# %%
# 2log fold change
rna_log2_treshold <- 4
# TODO : Change line. New data for processing. 
l1 <- abs(log2((raw_data[,"WM115"]+1)/(raw_data[,"WM266"]+1)))
l2 <- abs(log2((raw_data[,"WM793"]+1)/(raw_data[,"WM35"]+1)))
rna_log2_thr_mask <- ((l1 > rna_log2_treshold) + (l2 > rna_log2_treshold)) >= 1
data <- raw_data[rna_log2_thr_mask,]

# %%
write.csv(data, "../data/clean_data/RAN_total_count_data.csv", row.names = TRUE)

# %%
data
# Out:
#           WM115 WM266 WM793 WM35
# SIDG00004 18429  878    811 92573
# SIDG00005    38    0     58    28
# SIDG00011     6    1    533     1
# SIDG00035    37    0    175    52
# SIDG00048  2107   81    623   386
# SIDG00049    96  903   7571   102
# SIDG00063    77    0    616    28
# SIDG00064   338    2   1688  6869
# SIDG00066    29  774    129 15503
# SIDG00078   446   17  30772    28
# SIDG00084     3    7     16     0
# SIDG00107   353    1     93    49
# SIDG00109    16    0    216    31
# SIDG00110     2   15      0    19
# SIDG00149   522    8   2053    92
# SIDG00174    12   64      0    27
# SIDG00179 20856   21   1067 10263
# SIDG00193     0   13      2    81
# SIDG00203   235   38     73     0
# SIDG00205    10    4     17     0
# SIDG00232   431 3115      8 14166
# SIDG00235   221    8   1027   385
# SIDG00239   166   59     35  1440
# SIDG00246    29   43      2    48
# SIDG00247    82   15   2133    39
# SIDG00251    11   29     22   919
# SIDG00252   364    0      0     0
# SIDG00253     0  411      0   366
# SIDG00258   496 1555      0    35
# SIDG00260   416  336  54686  3109
# ⋮         ⋮     ⋮     ⋮     ⋮
# SIDG42081    0     1    49      1
# SIDG42085 1079    48  5223   4031
# SIDG42087 1681    95  1998   6345
# SIDG42099  487   893   280   5163
# SIDG42112  385   135    38    704
# SIDG42131  821    36   509    474
# SIDG42150  764   295  4666    156
# SIDG42152  433     1    58    225
# SIDG42175  354     7    10      0
# SIDG42205  290   180     2   1368
# SIDG42209  267   280    53   1386
# SIDG42217  365     7    19    119
# SIDG42231  115     1   426   1545
# SIDG42247    4     2  1600      3
# SIDG42252  112    54   583     11
# SIDG42271    4    84    11    558
# SIDG42280    0     0    36      0
# SIDG42285  356   167    30   1739
# SIDG42319   30     0   313     67
# SIDG42326  266     0  1135     16
# SIDG42332    7     0    35      0
# SIDG42338    9    15     0    115
# SIDG42340   63   133    25    720
# SIDG42372   22    11     0     97
# SIDG42380   30     0    25     60
# SIDG42403   25     0   264    560
# SIDG42419   48     0    71     68
# SIDG42437  202     9    93     51
# SIDG42441   70    33     2    326
# SIDG42464 3732  3116   101  17603
